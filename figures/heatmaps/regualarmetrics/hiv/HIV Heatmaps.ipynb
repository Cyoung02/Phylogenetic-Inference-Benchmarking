# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds",vmin = 0.05, vmax = 0.015)
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Unweighted Robinson Fould')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.011168  0.011168  0.011168  0.011168  0.011168
# 1  0.012183  0.008122  0.008122  0.008122  0.009137
# 2  0.010152  0.010152  0.010152  0.010152  0.011168
# 3  0.010152  0.010152  0.010152  0.010152  0.010152

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    
plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Weighted Robinson Fould')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  2.259431  0.705950  0.697431  0.690887  0.742803
# 1  2.355914  0.718943  0.704673  0.691608  0.728114
# 2  2.327238  0.718092  0.702293  0.692972  0.733975
# 3  2.490068  0.794521  0.768226  0.754018  0.789524

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Mantel Correlation- Spearman')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.997754  0.999131  0.999128  0.999127  0.999125
# 1  0.997742  0.999135  0.999133  0.999133  0.999132
# 2  0.997737  0.999136  0.999134  0.999133  0.999133
# 3  0.997757  0.999140  0.999138  0.999138  0.999137

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Mantel Correlation- Pearson')

print(dataframe)
# Out:
#           0         1         2         3         4
# 0  0.985268  0.999595  0.999622  0.999622  0.999622
# 1  0.985340  0.999590  0.999627  0.999627  0.999627
# 2  0.985507  0.999579  0.999618  0.999618  0.999618
# 3  0.982636  0.999446  0.999497  0.999497  0.999497

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Error Squared')

print(dataframe)
# Out:
#           0         1         2         3         4
# 0  0.013673  0.000314  0.000386  0.000357  0.000518
# 1  0.013876  0.000437  0.000435  0.000392  0.000589
# 2  0.013667  0.000395  0.000410  0.000388  0.000577
# 3  0.015693  0.000449  0.000474  0.000484  0.000470

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
