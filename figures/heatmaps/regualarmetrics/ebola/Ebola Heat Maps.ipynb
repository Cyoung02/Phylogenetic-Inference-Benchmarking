# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Unweighted Robinson Foulds (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.429949  0.456853  0.458883  0.464975  0.465990
# 1  0.431980  0.459898  0.457868  0.465990  0.464975
# 2  0.428934  0.457868  0.454822  0.457868  0.468020
# 3  0.438071  0.462944  0.457868  0.452792  0.465990

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Weighted Robinson Foulds (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  1.302056  0.182693  0.187221  0.186006  1.248718
# 1  1.316910  0.188956  0.194574  0.190045  1.145109
# 2  1.316920  0.189748  0.194147  0.193496  1.131281
# 3  1.347663  0.250810  0.248715  0.253072  0.960594

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Spearman (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.965144  0.965768  0.965681  0.965664  0.965237
# 1  0.965127  0.965591  0.965473  0.965797  0.965199
# 2  0.965131  0.965578  0.965667  0.965575  0.965239
# 3  0.965338  0.965702  0.965776  0.965755  0.965317

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Pearson (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.996782  0.999877  0.999874  0.999874  0.999858
# 1  0.996799  0.999872  0.999870  0.999868  0.999861
# 2  0.996843  0.999864  0.999860  0.999858  0.999850
# 3  0.996294  0.999738  0.999736  0.999731  0.999826

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    
plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Error Squared (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.043079  0.000563  0.000633  0.000519  0.042128
# 1  0.044205  0.000631  0.000639  0.000521  0.035179
# 2  0.043932  0.000707  0.000732  0.000732  0.035225
# 3  0.048735  0.002474  0.002365  0.002454  0.021972

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
