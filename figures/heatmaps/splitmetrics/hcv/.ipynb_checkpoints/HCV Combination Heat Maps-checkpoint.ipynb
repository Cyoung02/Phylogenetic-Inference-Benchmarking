# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt= '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.set_title('Unweighted Robinson Foulds (HCV)') 

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.071066  0.071066  0.071066  0.071066  0.071066
# 1  0.071066  0.071066  0.071066  0.071066  0.071066
# 2  0.068020  0.068020  0.068020  0.068020  0.068020
# 3  0.073096  0.073096  0.073096  0.073096  0.073096

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.set_title('Weighted Robinson Foulds (HCV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  4.027878  1.573215  5.746341  0.891917  7.912498
# 1  4.025422  1.575582  5.749933  0.888454  7.879694
# 2  3.998254  1.616791  5.329959  0.925942  7.891285
# 3  4.028734  1.580910  5.753094  0.897519  7.874595

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.set_title('Mantel Correlation- Spearman (HCV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.995154  0.998281  0.998244  0.998301  0.998233
# 1  0.995213  0.998294  0.998256  0.998310  0.998243
# 2  0.994950  0.997956  0.997914  0.997975  0.997924
# 3  0.995203  0.998284  0.998246  0.998305  0.998230

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9)) 
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.set_title('Mantel Correlation- Pearson (HCV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.990511  0.999266  0.999453  0.999520  0.999383
# 1  0.990596  0.999279  0.999468  0.999535  0.999395
# 2  0.991155  0.999257  0.999307  0.999449  0.999379
# 3  0.990411  0.999235  0.999445  0.999511  0.999360

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    
plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.set_title('Error Squared (HCV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.426615  0.047204  0.372383  0.005276  0.621864
# 1  0.426709  0.047883  0.370161  0.005434  0.612437
# 2  0.415985  0.047944  0.344899  0.004386  0.624273
# 3  0.428093  0.049177  0.366102  0.005861  0.606097

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
