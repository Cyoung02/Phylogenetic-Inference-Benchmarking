# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Unweighted Robinson Fould')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.429949  0.461929  0.461929  0.457868  0.457868
# 1  0.431980  0.463959  0.463959  0.459898  0.459898
# 2  0.428934  0.460914  0.460914  0.456853  0.456853
# 3  0.438071  0.470051  0.470051  0.465990  0.465990

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Weighted Robinson Fould')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  1.302056  0.182070  0.185063  0.188239  1.267147
# 1  1.316910  0.181289  0.182609  0.188105  1.270659
# 2  1.316920  0.181471  0.187204  0.188298  1.271826
# 3  1.347663  0.184864  0.190420  0.190329  1.275343

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Mantel Correlation- Spearman')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.965144  0.965794  0.965715  0.965608  0.965216
# 1  0.965127  0.965912  0.965779  0.965619  0.965222
# 2  0.965131  0.965907  0.965822  0.965693  0.965220
# 3  0.965338  0.965996  0.965812  0.965652  0.965262

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Mantel Correlation- Pearson')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.996782  0.999878  0.999873  0.999874  0.999858
# 1  0.996799  0.999878  0.999875  0.999875  0.999858
# 2  0.996843  0.999878  0.999874  0.999875  0.999858
# 3  0.996294  0.999877  0.999874  0.999874  0.999858

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    
plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = 'f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.set_title('Error Squared')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.043079  0.000578  0.000605  0.000659  0.043344
# 1  0.044205  0.000563  0.000582  0.000648  0.043454
# 2  0.043932  0.000564  0.000651  0.000650  0.043544
# 3  0.048735  0.000577  0.000608  0.000653  0.043764

# %%
from IPython.display import HTML
​
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
#   File "<ipython-input-6-1d00431473ae>", line 2
#     ​
#     ^
# SyntaxError: invalid character in identifier
