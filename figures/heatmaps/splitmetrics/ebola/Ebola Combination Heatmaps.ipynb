# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Unweighted Robinson Foulds (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.429949  0.461929  0.461929  0.457868  0.457868
# 1  0.431980  0.463959  0.463959  0.459898  0.459898
# 2  0.428934  0.460914  0.460914  0.456853  0.456853
# 3  0.438071  0.470051  0.470051  0.465990  0.465990

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Weighted Robinson Foulds (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  1.302056  0.182070  0.185063  0.188024  1.267147
# 1  1.316910  0.189838  0.193792  0.201325  1.166900
# 2  1.316920  0.190666  0.191890  0.207771  1.153451
# 3  1.347663  0.251269  0.250441  0.273854  0.979633

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Spearman (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.965144  0.965794  0.965715  0.965581  0.965216
# 1  0.965127  0.965873  0.965744  0.965646  0.965331
# 2  0.965131  0.965904  0.965775  0.965663  0.965291
# 3  0.965338  0.965927  0.965860  0.965687  0.965375

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Pearson (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.996782  0.999878  0.999873  0.999874  0.999858
# 1  0.996799  0.999878  0.999875  0.999875  0.999858
# 2  0.996843  0.999878  0.999874  0.999875  0.999858
# 3  0.996294  0.999877  0.999874  0.999874  0.999858

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    
plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Error Squared (Ebola)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.043079  0.000578  0.000605  0.000614  0.043344
# 1  0.044205  0.000635  0.000649  0.000837  0.036382
# 2  0.043932  0.000709  0.000682  0.000916  0.036462
# 3  0.048735  0.002423  0.002347  0.003048  0.022825

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
