# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 19})
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds",vmin = 0.05, vmax = 0.015)
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Unweighted Robinson Foulds (HIV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.011168  0.011168  0.011168  0.011168  0.011168
# 1  0.012183  0.012183  0.012183  0.012183  0.012183
# 2  0.010152  0.010152  0.010152  0.010152  0.010152
# 3  0.010152  0.010152  0.010152  0.010152  0.010152

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Weighted Robinson Foulds (HIV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  2.259431  0.704963  0.696676  0.713259  0.741746
# 1  2.355914  0.731902  0.707159  0.737341  0.730990
# 2  2.327238  0.728980  0.717456  0.728077  0.733820
# 3  2.490068  0.805186  0.774714  0.801413  0.790012

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Spearman (HIV)')

print (dataframe)
# Out:
#           0         1         2         3         4
# 0  0.997754  0.999131  0.999127  0.999126  0.999124
# 1  0.997742  0.999134  0.999130  0.999129  0.999129
# 2  0.997737  0.999134  0.999132  0.999131  0.999130
# 3  0.997757  0.999139  0.999137  0.999135  0.999135

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = '.4f', cmap = "Greens")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Mantel Correlation- Pearson (HIV)')

print(dataframe)
# Out:
#           0         1         2         3         4
# 0  0.985268  0.999599  0.999626  0.999627  0.999626
# 1  0.985340  0.999544  0.999626  0.999628  0.999626
# 2  0.985507  0.999539  0.999618  0.999619  0.999617
# 3  0.982636  0.999354  0.999497  0.999505  0.999496

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)

plt.figure(figsize=(12, 9))
ax = sns.heatmap(dataframe, annot = True, fmt = '0.4f', cmap = "Reds")
ax.set_xticklabels(['FastTree','IQTREE','IQTREE MFP','RAxML','PhyML'])
#plt.yticks(np.arange(4)+0.5,('True MSA','MAFFT','Clustal Omega','MUSCLE'), rotation=0, fontsize="9", va="center")
ax.tick_params(left=False)
ax.set_yticklabels([])
ax.set_title('Error Squared (HIV)')

print(dataframe)
# Out:
#           0         1         2         3         4
# 0  0.013673  0.000311  0.000383  0.000353  0.000514
# 1  0.013876  0.000506  0.000434  0.000539  0.000590
# 2  0.013667  0.000455  0.000505  0.000477  0.000575
# 3  0.015693  0.000581  0.000519  0.000467  0.000472

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
