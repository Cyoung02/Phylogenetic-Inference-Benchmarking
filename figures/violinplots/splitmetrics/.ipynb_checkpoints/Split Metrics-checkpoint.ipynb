# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

dataset = pd.read_csv("comboURF2.csv")
sns.set(rc={'figure.figsize':(12.75,7.5)}, font_scale = 1.5, style= "white")

#Specify individual plot colors
colors = {'f1':'b','i1':'lightgray','i4':'gray','mfp1':'#c88386','mfp4':'brown','r1':'#77b485','r4':'green','p1':'#d7c689','p4':'#bc9504',
          'f2':'b','i2':'lightgray','i5':'gray','mfp2':'#c88386','mfp5':'brown','r2':'#77b485','r5':'green','p2':'#d7c689','p5':'#bc9504',
          'f3':'b','i3':'lightgray','i6':'gray','mfp3':'#c88386','mfp6':'brown','r3':'#77b485','r6':'green','p3':'#d7c689','p6':'#bc9504'}

ax = sns.violinplot(x="metrics", y="numbers",
               scale = 'count',
               order = ['f1','i1','i4','mfp1','mfp4','r1','r4','p1','p4',
                        'f2','i2','i5','mfp2','mfp5','r2','r5','p2','p5',
                        'f3','i3','i6','mfp3','mfp6','r3','r6','p3','p6'],
               palette=colors,
               data=dataset)

#Legend
legend1 = mpatches.Patch(color='b', label='FastTree')
legend2 = mpatches.Patch(color='lightgray', label='IQ-TREE')
legend3 = mpatches.Patch(color='#c88386', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='#77b485', label='RAxML-NG')
legend5 = mpatches.Patch(color='#d7c689', label='PhyML')
legend = plt.legend(loc='upper left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

#Label and annotate
ax.text(0, 0.403,'*Darker plots represent \nFastTree/respective tool runs', fontsize=15)
ax.set_xticklabels(['','' , '','' ,'          HCV','' ,'' ,'', '','' , '','' ,'' ,'' , '          HIV','' ,'' ,'' ,'', '','' , '','' ,'' ,'' , 'Ebola','' ,'' , '','' , ''])
ax.set_ylabel('Normalized Unweighted Robinson Foulds')
ax.set_xlabel('')

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

dataset = pd.read_csv("comboWRF2.csv")
sns.set(rc={'figure.figsize':(12.75,7.5)}, font_scale = 1.5, style= "white")

#Specify individual plot colors
colors = {'f1':'b','i1':'lightgray','i4':'gray','mfp1':'#c88386','mfp4':'brown','r1':'#77b485','r4':'green','p1':'#d7c689','p4':'#bc9504',
          'f2':'b','i2':'lightgray','i5':'gray','mfp2':'#c88386','mfp5':'brown','r2':'#77b485','r5':'green','p2':'#d7c689','p5':'#bc9504',
          'f3':'b','i3':'lightgray','i6':'gray','mfp3':'#c88386','mfp6':'brown','r3':'#77b485','r6':'green','p3':'#d7c689','p6':'#bc9504'}

ax = sns.violinplot(x="metrics", y="numbers",
               scale = 'count',
               order = ['f1','i1','i4','mfp1','mfp4','r1','r4','p1','p4',
                        'f2','i2','i5','mfp2','mfp5','r2','r5','p2','p5',
                        'f3','i3','i6','mfp3','mfp6','r3','r6','p3','p6'],
               palette=colors,
               data=dataset)

#Legend
legend1 = mpatches.Patch(color='b', label='FastTree')
legend2 = mpatches.Patch(color='lightgray', label='IQ-TREE')
legend3 = mpatches.Patch(color='#c88386', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='#77b485', label='RAxML-NG')
legend5 = mpatches.Patch(color='#d7c689', label='PhyML')
legend = plt.legend(loc='upper right',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

#Label and annotate
ax.text(20, 5.9,'*Darker plots represent \nFastTree/respective tool\nruns', fontsize=15)
ax.set_xticklabels(['','' , '','' ,'          HCV','' ,'' ,'', '','' , '','' ,'' ,'' , '          HIV','' ,'' ,'' ,'', '','' , '','' ,'' ,'' , 'Ebola','' ,'' , '','' , ''])
ax.set_ylabel('Weighted Robinson Foulds')
ax.set_xlabel('')


plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

dataset = pd.read_csv("combospearman2.csv")
sns.set(rc={'figure.figsize':(12.75,7.5)}, font_scale = 1.5, style= "white")

#Specify individual plot colors
colors = {'f1':'b','i1':'lightgray','i4':'gray','mfp1':'#c88386','mfp4':'brown','r1':'#77b485','r4':'green','p1':'#d7c689','p4':'#bc9504',
          'f2':'b','i2':'lightgray','i5':'gray','mfp2':'#c88386','mfp5':'brown','r2':'#77b485','r5':'green','p2':'#d7c689','p5':'#bc9504',
          'f3':'b','i3':'lightgray','i6':'gray','mfp3':'#c88386','mfp6':'brown','r3':'#77b485','r6':'green','p3':'#d7c689','p6':'#bc9504'}

ax = sns.violinplot(x="metrics", y="numbers",
               scale = 'count',
               order = ['f1','i1','i4','mfp1','mfp4','r1','r4','p1','p4',
                        'f2','i2','i5','mfp2','mfp5','r2','r5','p2','p5',
                        'f3','i3','i6','mfp3','mfp6','r3','r6','p3','p6'],
               palette=colors,
               data=dataset)

#Legend
legend1 = mpatches.Patch(color='b', label='FastTree')
legend2 = mpatches.Patch(color='lightgray', label='IQ-TREE')
legend3 = mpatches.Patch(color='#c88386', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='#77b485', label='RAxML-NG')
legend5 = mpatches.Patch(color='#d7c689', label='PhyML')
legend = plt.legend(loc='lower left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

#Label and annotate
ax.text(0, 0.952,'*Darker plots represent \nFastTree/respective tool runs', fontsize=15)
ax.set_xticklabels(['','' , '','' ,'          HCV','' ,'' ,'', '','' , '','' ,'' ,'' , '          HIV','' ,'' ,'' ,'', '','' , '','' ,'' ,'' , 'Ebola','' ,'' , '','' , ''])
ax.set_ylabel('Mantel Correlation- Spearman')
ax.set_xlabel('')


plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

dataset = pd.read_csv("combopearson2.csv")
sns.set(rc={'figure.figsize':(12.75,7.5)}, font_scale = 1.5, style= "white")

#Specify individual plot colors
colors = {'f1':'b','i1':'lightgray','i4':'gray','mfp1':'#c88386','mfp4':'brown','r1':'#77b485','r4':'green','p1':'#d7c689','p4':'#bc9504',
          'f2':'b','i2':'lightgray','i5':'gray','mfp2':'#c88386','mfp5':'brown','r2':'#77b485','r5':'green','p2':'#d7c689','p5':'#bc9504',
          'f3':'b','i3':'lightgray','i6':'gray','mfp3':'#c88386','mfp6':'brown','r3':'#77b485','r6':'green','p3':'#d7c689','p6':'#bc9504'}

ax = sns.violinplot(x="metrics", y="numbers",
               scale = 'count',
               order = ['f1','i1','i4','mfp1','mfp4','r1','r4','p1','p4',
                        'f2','i2','i5','mfp2','mfp5','r2','r5','p2','p5',
                        'f3','i3','i6','mfp3','mfp6','r3','r6','p3','p6'],
               palette=colors,
               data=dataset)

#Legend
legend1 = mpatches.Patch(color='b', label='FastTree')
legend2 = mpatches.Patch(color='lightgray', label='IQ-TREE')
legend3 = mpatches.Patch(color='#c88386', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='#77b485', label='RAxML-NG')
legend5 = mpatches.Patch(color='#d7c689', label='PhyML')
legend = plt.legend(loc='lower right',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

#Label and annotate
ax.text(20.2,0.9844,'*Darker plots represent \nFastTree/respective tool\nruns', fontsize=15)
ax.set_xticklabels(['','' , '','' ,'          HCV','' ,'' ,'', '','' , '','' ,'' ,'' , '          HIV','' ,'' ,'' ,'', '','' , '','' ,'' ,'' , 'Ebola','' ,'' , '','' , ''])
ax.set_ylabel('Mantel Correlation- Pearson')
ax.set_xlabel('')


plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

dataset = pd.read_csv("comboerrorsq2.csv")
sns.set(rc={'figure.figsize':(12.75,7.5)}, font_scale = 1.5, style= "white")

#Specify individual plot colors
colors = {'f1':'b','i1':'lightgray','i4':'gray','mfp1':'#c88386','mfp4':'brown','r1':'#77b485','r4':'green','p1':'#d7c689','p4':'#bc9504',
          'f2':'b','i2':'lightgray','i5':'gray','mfp2':'#c88386','mfp5':'brown','r2':'#77b485','r5':'green','p2':'#d7c689','p5':'#bc9504',
          'f3':'b','i3':'lightgray','i6':'gray','mfp3':'#c88386','mfp6':'brown','r3':'#77b485','r6':'green','p3':'#d7c689','p6':'#bc9504'}

ax = sns.violinplot(x="metrics", y="numbers",
               scale = 'count',
               order = ['f1','i1','i4','mfp1','mfp4','r1','r4','p1','p4',
                        'f2','i2','i5','mfp2','mfp5','r2','r5','p2','p5',
                        'f3','i3','i6','mfp3','mfp6','r3','r6','p3','p6'],
               palette=colors,
               data=dataset)

#Legend
legend1 = mpatches.Patch(color='b', label='FastTree')
legend2 = mpatches.Patch(color='lightgray', label='IQ-TREE')
legend3 = mpatches.Patch(color='#c88386', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='#77b485', label='RAxML-NG')
legend5 = mpatches.Patch(color='#d7c689', label='PhyML')
legend = plt.legend(loc='upper right',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

#Label and annotate
ax.text(20, 0.554,'*Darker plots represent \nFastTree/respective tool\nruns', fontsize=15)
ax.set_xticklabels(['','' , '','' ,'          HCV','' ,'' ,'', '','' , '','' ,'' ,'' , '          HIV','' ,'' ,'' ,'', '','' , '','' ,'' ,'' , 'Ebola','' ,'' , '','' , ''])
ax.set_ylabel('Error Squared')
ax.set_xlabel('')


plt.show()

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
