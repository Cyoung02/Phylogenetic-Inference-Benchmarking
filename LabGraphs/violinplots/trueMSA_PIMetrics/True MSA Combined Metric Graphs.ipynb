# %%
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with open('URF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    dataframe = dataframe.T

sns.set_style("white")
ax = sns.violinplot(data=dataframe, scale = 'count', palette = ['y','m','r','b','g'])

ax.set_xticklabels(['', '', 'HCV', '', '','' , '', 'HIV', '', '','' , '', 'Ebola', '', ''])
ax.set_ylabel('Normalized Unweighted Robinson Foulds')

legend1 = mpatches.Patch(color='y', label='FastTree')
legend2 = mpatches.Patch(color='m', label='IQ-TREE')
legend3 = mpatches.Patch(color='r', label='IQ-TREE MFP')
legend4 = mpatches.Patch(color='b', label='RAxML-NG')
legend5 = mpatches.Patch(color='g', label='PhyML')
legend = plt.legend(loc='upper left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

plt.show()
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with open('WRF') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    dataframe = dataframe.T

sns.set_style("white")
ax = sns.violinplot(data=dataframe, scale = 'count', palette = ['y','m','r','b','g'])

ax.set_xticklabels(['', '', 'HCV', '', '','' , '', 'HIV', '', '','' , '', 'Ebola', '', ''])
ax.set_ylabel('Weighted Robinson Fould')
sns.set(rc={'figure.figsize':(15,8.27)})

legend1 = mpatches.Patch(color='y', label='FastTree')
legend2 = mpatches.Patch(color='m', label='IQTREE')
legend3 = mpatches.Patch(color='r', label='IQTREE MFP')
legend4 = mpatches.Patch(color='b', label='RAxML-NG')
legend5 = mpatches.Patch(color='g', label='PhyML')
legend = plt.legend(loc='upper left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with open('spearman') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    dataframe = dataframe.T

sns.set_style("white")
ax = sns.violinplot(data=dataframe, scale = 'count', palette = ['y','m','r','b','g'])

ax.set_xticklabels(['', '', 'HCV', '', '','' , '', 'HIV', '', '','' , '', 'Ebola', '', ''])
ax.set_ylabel('Mantel Correlation- Spearman')

sns.set(rc={'figure.figsize':(15,8.27)})
legend1 = mpatches.Patch(color='y', label='FastTree')
legend2 = mpatches.Patch(color='m', label='IQTREE')
legend3 = mpatches.Patch(color='r', label='IQTREE MFP')
legend4 = mpatches.Patch(color='b', label='RAxML-NG')
legend5 = mpatches.Patch(color='g', label='PhyML')
legend = plt.legend(loc='lower left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with open('pearson') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    dataframe = dataframe.T

sns.set_style("white")
ax = sns.violinplot(data=dataframe, scale = 'count', palette = ['y','m','r','b','g'])

ax.set_xticklabels(['', '', 'HCV', '', '','' , '', 'HIV', '', '','' , '', 'Ebola', '', ''])
ax.set_ylabel('Mantel Correlation- Pearson')

sns.set(rc={'figure.figsize':(15,8.27)})
legend1 = mpatches.Patch(color='y', label='FastTree')
legend2 = mpatches.Patch(color='m', label='IQTREE')
legend3 = mpatches.Patch(color='r', label='IQTREE MFP')
legend4 = mpatches.Patch(color='b', label='RAxML-NG')
legend5 = mpatches.Patch(color='g', label='PhyML')
legend = plt.legend(loc='lower left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with open('errorSq') as f:
    data = [list(map(float, col.split())) for col in f.read().split('\n\n')]  
    dataframe = pd.DataFrame(data)
    dataframe = dataframe.T

sns.set_style("white")
ax = sns.violinplot(data=dataframe, scale = 'count', palette = ['y','m','r','b','g'])

ax.set_xticklabels(['', '', 'HCV', '', '','' , '', 'HIV', '', '','' , '', 'Ebola', '', ''])
ax.set_ylabel('Error Squared')

sns.set(rc={'figure.figsize':(15,8.27)})
legend1 = mpatches.Patch(color='y', label='FastTree')
legend2 = mpatches.Patch(color='m', label='IQTREE')
legend3 = mpatches.Patch(color='r', label='IQTREE MFP')
legend4 = mpatches.Patch(color='b', label='RAxML-NG')
legend5 = mpatches.Patch(color='g', label='PhyML')
legend = plt.legend(loc='upper left',handles=[legend1,legend2,legend3,legend4,legend5])
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')

plt.show()

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
